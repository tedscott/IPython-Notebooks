# %%
R.Version()
# Out:
# $platform
# [1] "x86_64-w64-mingw32"
#
# $arch
# [1] "x86_64"
#
# $os
# [1] "mingw32"
#
# $system
# [1] "x86_64, mingw32"
#
# $status
# [1] ""
#
# $major
# [1] "3"
#
# $minor
# [1] "1.3"
#
# $year
# [1] "2015"
#
# $month
# [1] "03"
#
# $day
# [1] "09"
#
# $`svn rev`
# [1] "67962"
#
# $language
# [1] "R"
#
# $version.string
# [1] "R version 3.1.3 (2015-03-09)"
#
# $nickname
# [1] "Smooth Sidewalk"
